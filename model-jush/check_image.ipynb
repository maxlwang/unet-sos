# %%
from matplotlib import image, pyplot
import numpy as np

# %%
test_path = '/sim/asinghvi/wheat_processed_v2/test/'

# %%
img_pred = image.imread(test_path + '11_predict.png')
img_true = image.imread(test_path + '11_truth.png')
print(img_pred.shape)
print(img_true.shape)
# Out:
# (256, 256)
# (256, 256)

# %%
img_pred.dtype
# Out:
# dtype('float32')

# %%
pyplot.imshow(img_pred)
pyplot.show()

# %%
print(img_true[0][255])
# Out:
# 0.6039216
